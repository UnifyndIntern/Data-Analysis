# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Sep 22 16:31:39 2017

@author: dhaval
"""
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing data
df = pd.read_excel('Master Sales Data.xlsx')

# %%
# Delete Unnecessary Columns in Data
cleaned_data = df.drop(['Sr. No.'], axis = 1)
cleaned_data.drop(['Yardi - Lease Details'], axis = 1, inplace = True)
cleaned_data.drop(['Lease Code'], axis = 1, inplace = True)

# %%
cleaned_data
# Out:
#                       Brand Name         Floor       Unit Nos         Format  \
# 0                  Planet Sports  Lower Ground        GF - 01         Inline
# 1                           Nike  Lower Ground        GF - 1A         Inline
# 2                        Levis    Lower Ground        GF - 02         Inline
# 3                      UCB - Old  Lower Ground        GF - 03         Inline
# 4                            TCP  Lower Ground        GF - 03         Inline
# 5                       Woodland  Lower Ground        GF - 04         Inline
# 6                      Sports XS  Lower Ground   GF - 05 & 06         Inline
# 7                          Mochi  Lower Ground        GF - 07         Inline
# 8                   Just Watches  Lower Ground        GF - 08         Inline
# 9                          Casio  Lower Ground        GF - 09         Inline
# 10                      OM Books  Lower Ground        GF - 10         Inline
# ...

# %%
cleaned_data.columns.values
# Out:
# array(['Brand Name', 'Floor', 'Unit Nos', 'Format',
#        'Category - New format', 'Source', 'Trading Date',
#        'Term Expiry Date', 'MG/PRS', 'Carpet Area', 'Chargeable Area',
#        'Revenue Share %', 'Apr 2013 Sales', 'May 2013 Sales',
#        'June 2013 Sales', 'July 2013 Sales', 'Aug 2013 Sales',
#        'Sep 2013 Sales', 'Oct 2013 Sales', 'Nov 2013 Sales',
#        'Dec 2013 Sales', 'Jan 2014 Sales', 'Feb 2014 Sales',
#        'Mar 2014 Sales', 'Apr 2014 Sales', 'May 2014 Sales',
#        'Jun 2014 Sales', 'Jul 2014 Sales', 'Aug 2014 Sales',
#        'Sep 2014 Sales', 'Oct 2014 Sales', 'Nov 2014 Sales',
#        'Dec 2014 Sales', 'Jan 2015 Sales', 'Feb 2015 Sales',
#        'Mar 2015 Sales', 'Apr 2015 Sales', 'May 2015 Sales',
#        'June 2015 Sales', 'July 2015 Sales', 'Aug 2015 Sales',
#        'Sep 2015 Sales', 'Oct 2015 Sales', 'Nov 2015 Sales',
#        'Dec 2015 Sales', 'Jan 2016 Sales', 'Feb 2016 Sales',
# ...

# %%
rent = ['Apr 2013 \nR + RS',
       'May 2013 \nR + RS', 'Jun 2013 \nR + RS', 'Jul 2013 \nR + RS',
       'Aug 2013 \nR + RS', 'Sep 2013 \nR + RS', 'Oct 2013 \nR + RS',
       'Nov 2013 \nR + RS', 'Dec 2013 \nR + RS', 'Jan 2014\n R + RS',
       'Feb 2014\n R + RS', 'Mar 2014\n R + RS', 'Apr 2014\n R + RS',
       'May 2014\n R + RS', 'Jun 2014\n R + RS', 'Jul 2014\n R + RS',
       'Aug 2014\n R + RS', 'Sep 2014\n R + RS', 'Oct 2014\n R + RS',
       'Nov 2014\n R + RS', 'Dec 2014\n R + RS', 'Jan 2015\n R + RS',
       'Feb 2015\n R + RS', 'Mar 2015\n R + RS', 'Apr 2015\n R + RS',
       'May 2015\n R + RS', 'June 2015\n R + RS', 'July 2015\n R + RS',
       'Aug 2015\n R + RS', 'Sep 2015\n R + RS', 'Oct 2015\n R + RS',
       'Nov 2015\n R + RS', 'Dec 2015\n R + RS', 'Jan 2016\n R + RS',
       'Feb 2016\n R + RS', 'Mar 2016\n R + RS', 'Apr 2016\n R + RS',
       'May 2016\n R + RS', 'Jun 2016\n R + RS', 'Jul 2016\n R + RS',
       'Aug 2016\n R + RS', 'Sep 2016\n R + RS', 'Oct 2016\n R + RS',
       'Nov 2016\n R + RS', 'Dec 2016\n R + RS', 'Jan 2017\n R + RS',
       'Feb 2017\n R + RS', 'Mar 2017\n R + RS', 'Apr 2017\n R + RS',
       'May 2017\n R + RS', 'Jun 2017\n R + RS', 'Jul 2017\n R + RS']

# %%
sales = ['Apr 2013 Sales', 'May 2013 Sales',
       'June 2013 Sales', 'July 2013 Sales', 'Aug 2013 Sales',
       'Sep 2013 Sales', 'Oct 2013 Sales', 'Nov 2013 Sales',
       'Dec 2013 Sales', 'Jan 2014 Sales', 'Feb 2014 Sales',
       'Mar 2014 Sales', 'Apr 2014 Sales', 'May 2014 Sales',
       'Jun 2014 Sales', 'Jul 2014 Sales', 'Aug 2014 Sales',
       'Sep 2014 Sales', 'Oct 2014 Sales', 'Nov 2014 Sales',
       'Dec 2014 Sales', 'Jan 2015 Sales', 'Feb 2015 Sales',
       'Mar 2015 Sales', 'Apr 2015 Sales', 'May 2015 Sales',
       'June 2015 Sales', 'July 2015 Sales', 'Aug 2015 Sales',
       'Sep 2015 Sales', 'Oct 2015 Sales', 'Nov 2015 Sales',
       'Dec 2015 Sales', 'Jan 2016 Sales', 'Feb 2016 Sales',
       'Mar 2016 Sales', 'Apr 2016 Sales', 'May 2016 Sales',
       'Jun 2016 Sales', 'Jul 2016 Sales', 'Aug 2016 Sales',
       'Sep 2016 Sales', 'Oct 2016 Sales', 'Nov 2016 Sales',
       'Dec 2016 Sales', 'Jan 2017 Sales', 'Feb 2017 Sales',
       'Mar 2017 Sales', 'Apr 2017 Sales', 'May 2017 Sales',
       'Jun 2017 Sales', 'Jul 2017 Sales']
old_td = []
rent = ['Apr 2013 \nR + RS',
       'May 2013 \nR + RS', 'Jun 2013 \nR + RS', 'Jul 2013 \nR + RS',
       'Aug 2013 \nR + RS', 'Sep 2013 \nR + RS', 'Oct 2013 \nR + RS',
       'Nov 2013 \nR + RS', 'Dec 2013 \nR + RS', 'Jan 2014\n R + RS',
       'Feb 2014\n R + RS', 'Mar 2014\n R + RS', 'Apr 2014\n R + RS',
       'May 2014\n R + RS', 'Jun 2014\n R + RS', 'Jul 2014\n R + RS',
       'Aug 2014\n R + RS', 'Sep 2014\n R + RS', 'Oct 2014\n R + RS',
       'Nov 2014\n R + RS', 'Dec 2014\n R + RS', 'Jan 2015\n R + RS',
       'Feb 2015\n R + RS', 'Mar 2015\n R + RS', 'Apr 2015\n R + RS',
       'May 2015\n R + RS', 'June 2015\n R + RS', 'July 2015\n R + RS',
       'Aug 2015\n R + RS', 'Sep 2015\n R + RS', 'Oct 2015\n R + RS',
       'Nov 2015\n R + RS', 'Dec 2015\n R + RS', 'Jan 2016\n R + RS',
       'Feb 2016\n R + RS', 'Mar 2016\n R + RS', 'Apr 2016\n R + RS',
       'May 2016\n R + RS', 'Jun 2016\n R + RS', 'Jul 2016\n R + RS',
       'Aug 2016\n R + RS', 'Sep 2016\n R + RS', 'Oct 2016\n R + RS',
       'Nov 2016\n R + RS', 'Dec 2016\n R + RS', 'Jan 2017\n R + RS',
       'Feb 2017\n R + RS', 'Mar 2017\n R + RS', 'Apr 2017\n R + RS',
       'May 2017\n R + RS', 'Jun 2017\n R + RS', 'Jul 2017\n R + RS']

# %%
first = ((cleaned_data[sales[0]] / cleaned_data['Carpet Area'])) / cleaned_data[rent[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c0b5063f4c51> in <module>()
# ----> 1 first = (int(cleaned_data[sales[0]] / cleaned_data['Carpet Area'])) / cleaned_data[rent[0]]
#
# /home/dhaval/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
first = np.nan_to_num(first)

# %%
first = pd.Series(first.astype(int))

# %%
first
# Out:
# 0       5
# 1       0
# 2       7
# 3       4
# 4       0
# 5       4
# 6       7
# 7       0
# 8       6
# 9      10
# 10      0
# 11      3
# 12      0
# 13      2
# 14      0
# 15      0
# 16      1
# 17      4
# 18      0
# 19      2
# 20      0
# 21      0
# 22      1
# 23      0
# 24      6
# 25     13
# 26      0
# 27      6
# 28      7
# 29     27
#        ..
# 301     3
# 302     0
# 303     7
# 304     2
# 305     0
# 306    16
# 307     6
# 308     0
# 309    26
# 310     0
# 311    31
# 312    30
# 313    16
# 314    26
# 315     0
# 316    37
# 317    35
# 318    35
# 319    26
# 320     0
# 321    59
# 322     0
# 323     3
# 324    21
# 325     0
# 326     0
# 327     0
# 328     5
# 329     0
# 330     0
# Length: 331, dtype: int64

# %%
first.replace(0, np.nan)
# Out:
# 0       5.0
# 1       NaN
# 2       7.0
# 3       4.0
# 4       NaN
# 5       4.0
# 6       7.0
# 7       NaN
# 8       6.0
# 9      10.0
# 10      NaN
# 11      3.0
# 12      NaN
# 13      2.0
# 14      NaN
# 15      NaN
# 16      1.0
# 17      4.0
# 18      NaN
# 19      2.0
# 20      NaN
# 21      NaN
# 22      1.0
# 23      NaN
# 24      6.0
# 25     13.0
# 26      NaN
# 27      6.0
# 28      7.0
# 29     27.0
#        ...
# 301     3.0
# 302     NaN
# 303     7.0
# 304     2.0
# 305     NaN
# 306    16.0
# 307     6.0
# 308     NaN
# 309    26.0
# 310     NaN
# 311    31.0
# 312    30.0
# 313    16.0
# 314    26.0
# 315     NaN
# 316    37.0
# 317    35.0
# 318    35.0
# 319    26.0
# 320     NaN
# 321    59.0
# 322     NaN
# 323     3.0
# 324    21.0
# 325     NaN
# 326     NaN
# 327     NaN
# 328     5.0
# 329     NaN
# 330     NaN
# Length: 331, dtype: float64

# %%
rent = ['Apr 2013 \nR + RS',
       'May 2013 \nR + RS', 'Jun 2013 \nR + RS', 'Jul 2013 \nR + RS',
       'Aug 2013 \nR + RS', 'Sep 2013 \nR + RS', 'Oct 2013 \nR + RS',
       'Nov 2013 \nR + RS', 'Dec 2013 \nR + RS', 'Jan 2014\n R + RS',
       'Feb 2014\n R + RS', 'Mar 2014\n R + RS', 'Apr 2014\n R + RS',
       'May 2014\n R + RS', 'Jun 2014\n R + RS', 'Jul 2014\n R + RS',
       'Aug 2014\n R + RS', 'Sep 2014\n R + RS', 'Oct 2014\n R + RS',
       'Nov 2014\n R + RS', 'Dec 2014\n R + RS', 'Jan 2015\n R + RS',
       'Feb 2015\n R + RS', 'Mar 2015\n R + RS', 'Apr 2015\n R + RS',
       'May 2015\n R + RS', 'June 2015\n R + RS', 'July 2015\n R + RS',
       'Aug 2015\n R + RS', 'Sep 2015\n R + RS', 'Oct 2015\n R + RS',
       'Nov 2015\n R + RS', 'Dec 2015\n R + RS', 'Jan 2016\n R + RS',
       'Feb 2016\n R + RS', 'Mar 2016\n R + RS', 'Apr 2016\n R + RS',
       'May 2016\n R + RS', 'Jun 2016\n R + RS', 'Jul 2016\n R + RS',
       'Aug 2016\n R + RS', 'Sep 2016\n R + RS', 'Oct 2016\n R + RS',
       'Nov 2016\n R + RS', 'Dec 2016\n R + RS', 'Jan 2017\n R + RS',
       'Feb 2017\n R + RS', 'Mar 2017\n R + RS', 'Apr 2017\n R + RS',
       'May 2017\n R + RS', 'Jun 2017\n R + RS', 'Jul 2017\n R + RS']
old_td = ['Apr 2013 \nTD', 'May  2013 \nTD', 'Jun  2013 \nTD',
       'Jul  2013 \nTD', 'Aug 2013 \nTD', 'Sep 2013 \nTD', 'Oct 2013 \nTD',
       'Nov 2013 \nTD', 'Dec 2013 \nTD', 'Jan 2014 \nTD', 'Feb 2014 \nTD',
       'Mar 2014 \nTD', 'Apr 2014 \nTD', 'May 2014 \nTD', 'Jun 2014 \nTD',
       'Jul 2014 \nTD', 'Aug 2014 \nTD', 'Sep 2014 \nTD', 'Oct 2014 \nTD',
       'Nov 2014 \nTD', 'Dec 2014 \nTD', 'Jan 2015 \nTD', 'Feb 2015 \nTD',
       'Mar 2015 \nTD', 'Apr 2015 \nTD', 'May 2015 \nTD', 'June 2015 \nTD',
       'July 2015 \nTD', 'Aug 2015 \nTD', 'Sep 2015 \nTD', 'Oct 2015 \nTD',
       'Nov 2015 \nTD', 'Dec 2015 \nTD', 'Jan 2016 \nTD', 'Feb 2016 \nTD',
       'Mar 2016 \nTD', 'Apr 2016 \nTD', 'May 2016 \nTD', 'Jun 2016 \nTD',
       'Jul 2016 \nTD', 'Aug 2016 \nTD', 'Sep 2016 \nTD', 'Oct 2016 \nTD',
       'Nov 2016 \nTD', 'Dec 2016 \nTD', 'Jan 2017 \nTD', 'Feb 2017 \nTD',
       'Mar 2017 \nTD', 'Apr 2017 \nTD', 'May 2017 \nTD', 'Jun 2017 \nTD',
       'Jul 2017 \nTD']
for x,y in old_td, rent:
    print(cleaned_data[x],cleaned_data[y])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-ec0aa3ae23b0> in <module>()
#      31        'Mar 2017 \nTD', 'Apr 2017 \nTD', 'May 2017 \nTD', 'Jun 2017 \nTD',
#      32        'Jul 2017 \nTD']
# ---> 33 for x,y in old_td, rent:
#      34     print(cleaned_data[x],cleaned_data[y])
#      35
#
# ValueError: too many values to unpack (expected 2)

# %%
# Out:
# 0       5
# 1       0
# 2       7
# 3       4
# 4       0
# 5       4
# 6       7
# 7       0
# 8       6
# 9      10
# 10      0
# 11      3
# 12      0
# 13      2
# 14      0
# 15      0
# 16      1
# 17      4
# 18      0
# 19      2
# 20      0
# 21      0
# 22      1
# 23      0
# 24      6
# 25     13
# 26      0
# 27      6
# 28      7
# 29     27
#        ..
# 301     3
# 302     0
# 303     7
# 304     2
# 305     0
# 306    16
# 307     6
# 308     0
# 309    26
# 310     0
# 311    31
# 312    30
# 313    16
# 314    26
# 315     0
# 316    37
# 317    35
# 318    35
# 319    26
# 320     0
# 321    59
# 322     0
# 323     3
# 324    21
# 325     0
# 326     0
# 327     0
# 328     5
# 329     0
# 330     0
# Length: 331, dtype: int64
